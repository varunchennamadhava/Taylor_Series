# %%
import math
from decimal import *
from prettytable import PrettyTable


def absoluteError(measured, actual):
    return abs(measured - actual)

def relativeError(absError, actual):
    return absError / actual

def taylorSeriesCos(x,n):
    summation = 0
    for i in range(0,n+1):
        summation = (Decimal(((-1)**i))*(Decimal((x**(2*i)))/(Decimal(math.factorial(2*i))))) + summation
    summation = float(summation)
    return summation    

def main():
    valueOfXs = [0.25,0.5,1,2]
    valueOfNs = [4,16,64]
    cosoneforth=['x = 0.25']
    cosonehalf =['x = 0.5']
    cosone = ['x = 1']
    costwo = ['x = 2']
    for w in range(0,len(valueOfNs)):
        cosoneforth.append(taylorSeriesCos(0.25,valueOfNs[w]))
        cosonehalf.append(taylorSeriesCos(0.5,valueOfNs[w]))
        cosone.append(taylorSeriesCos(1,valueOfNs[w]))
        costwo.append(taylorSeriesCos(2,valueOfNs[w]))
    
    
    
#     print(cosone)
    
    table = PrettyTable()
    table.field_names = ["  ", "n = 4", "n = 16", "n = 64"]  
    table.add_row(cosoneforth)
    table.add_row(cosonehalf)
    table.add_row(cosone)
    table.add_row(costwo)
    print("Data for Taylor Series: ")
    print(table)
    
    print
    print
    
    print("Absolute Error")
    
    abscosoneforth=['x = 0.25']
    abscosonehalf =['x = 0.5']
    abscosone = ['x = 1']
    abscostwo = ['x = 2']
    
    tableAbsoluteError = PrettyTable()
    for ww in range(1, 4):
        abscosoneforth.append(absoluteError(cosoneforth[ww], math.cos(valueOfXs[ww-1])))
        abscosonehalf.append(absoluteError(cosonehalf[ww], math.cos(valueOfXs[ww-1])))
        abscosone.append(absoluteError(cosone[ww], math.cos(valueOfXs[ww-1])))
        abscostwo.append(absoluteError(costwo[ww], math.cos(valueOfXs[ww-1])))
    
#     print abscosoneforth
#     print abscosonehalf
#     print abscosone
#     print abscostwo

    tableAbsoluteError = PrettyTable()
    tableAbsoluteError.field_names = ["  ", "n = 4", "n = 16", "n = 64"]
    tableAbsoluteError.add_row(abscosoneforth)
    tableAbsoluteError.add_row(abscosonehalf)
    tableAbsoluteError.add_row(abscosone)
    tableAbsoluteError.add_row(abscostwo)
    print(tableAbsoluteError)
    
    

        


main()
# Out:
# Data for Taylor Series:
# +----------+-----------------+-----------------+-----------------+
# |          |      n = 4      |      n = 16     |      n = 64     |
# +----------+-----------------+-----------------+-----------------+
# | x = 0.25 |  0.968912421711 |  0.968912421711 |  0.968912421711 |
# | x = 0.5  |  0.877582562159 |  0.87758256189  |  0.87758256189  |
# |  x = 1   |  0.540302579365 |  0.540302305868 |  0.540302305868 |
# |  x = 2   | -0.415873015873 | -0.416146836547 | -0.416146836547 |
# +----------+-----------------+-----------------+-----------------+
#
#
# Absolute Error
# +----------+-------------------+-----------------+----------------+
# |          |       n = 4       |      n = 16     |     n = 64     |
# +----------+-------------------+-----------------+----------------+
# | x = 0.25 | 2.62678767626e-13 | 0.0913298598203 | 0.428610115843 |
# | x = 0.5  |  0.0913298595517  |       0.0       | 0.337280256022 |
# ...
