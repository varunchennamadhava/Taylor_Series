# %%
import math
from decimal import *
from prettytable import PrettyTable


def absoluteError(measured, actual):
    return abs(measured - actual)

def relativeError(measured, actual):
    u = abs(measured - actual) / (actual)
    return u * 100

def taylorSeriesSin(x,n):
    summation = 0
    for i in range(0,n+1):
        summation = (Decimal(x**(2*i)))/(math.factorial(2*i)) + summation
#         summation = (Decimal(((-1)**i))*(Decimal((x**(2*i + 1)))/(Decimal(math.factorial(2*i + 1))))) + summation
    
    summation = float(summation)
    return summation    

def main():
    valueOfXs = [0.25,0.5,1,2]
    valueOfNs = [4,16,64]
    sinoneforth=['x = 0.25']
    sinonehalf =['x = 0.5']
    sinone = ['x = 1']
    sintwo = ['x = 2']
    for w in range(0,len(valueOfNs)):
        sinoneforth.append(taylorSeriesSin(0.25,valueOfNs[w]))
        sinonehalf.append(taylorSeriesSin(0.5,valueOfNs[w]))
        sinone.append(taylorSeriesSin(1,valueOfNs[w]))
        sintwo.append(taylorSeriesSin(2,valueOfNs[w]))
    
    
    
#     print(cosone)
    
    table = PrettyTable()
    table.field_names = ["  ", "n = 4", "n = 16", "n = 64"]  
    table.add_row(sinoneforth)
    table.add_row(sinonehalf)
    table.add_row(sinone)
    table.add_row(sintwo)
    print("sin(x)")
    print("Data for Taylor Series: ")
    print(table)
    
    print
    print
    
    print("Absolute Error: ")
    
    abssinoneforth=['x = 0.25']
    abssinonehalf =['x = 0.5']
    abssinone = ['x = 1']
    abssintwo = ['x = 2']
    
    tableAbsoluteError = PrettyTable()
    for ww in range(1, 4):
        abssinoneforth.append(absoluteError(sinoneforth[ww], math.cosh(0.25)))
        abssinonehalf.append(absoluteError(sinonehalf[ww], math.cosh(0.5)))
        abssinone.append(absoluteError(sinone[ww], math.cosh(1)))
        abssintwo.append(absoluteError(sintwo[ww], math.cosh(2)))


    tableAbsoluteError = PrettyTable()
    tableAbsoluteError.field_names = ["  ", "n = 4", "n = 16", "n = 64"]
    tableAbsoluteError.add_row(abssinoneforth)
    tableAbsoluteError.add_row(abssinonehalf)
    tableAbsoluteError.add_row(abssinone)
    tableAbsoluteError.add_row(abssintwo)
    print(tableAbsoluteError)
    
    print 
    print 
     
    relativesinoneforth=['x = 0.25']
    relativesinonehalf =['x = 0.5']
    relativesinone = ['x = 1']
    relativesintwo = ['x = 2']
    
    for ww in range(1, 4):
        relativesinoneforth.append(relativeError(sinoneforth[ww], math.cosh(0.25)))
        relativesinonehalf.append(relativeError(sinonehalf[ww], math.cosh(0.5)))
        relativesinone.append(relativeError(sinone[ww], math.cosh(1)))
        relativesintwo.append(relativeError(sintwo[ww], math.cosh(2)))
    
    print("Relative Error: ")
    
    tableRelativeError = PrettyTable()
    tableRelativeError.field_names = ["  ", "n = 4", "n = 16", "n = 64"]
    tableRelativeError.add_row(relativesinoneforth)
    tableRelativeError.add_row(relativesinonehalf)
    tableRelativeError.add_row(relativesinone)
    tableRelativeError.add_row(relativesintwo)
    print(tableRelativeError)
    
main()
# Out:
# sin(x)
# Data for Taylor Series:
# +----------+-------------------+-------------------+--------------------+
# |          |       n = 4       |       n = 16      |       n = 64       |
# +----------+-------------------+-------------------+--------------------+
# | x = 0.25 |  3.7844218905e-10 | 2.06019595635e-55 | 2.23955130759e-293 |
# | x = 0.5  | 9.68812003968e-08 | 8.84847425589e-46 | 7.62079819788e-255 |
# |  x = 1   | 2.48015873016e-05 | 3.80039075485e-36 | 2.5932232486e-216  |
# |  x = 2   |  0.00634920634921 | 1.63225540041e-26 | 8.82428144989e-178 |
# +----------+-------------------+-------------------+--------------------+
#
#
# Absolute Error:
# +----------+---------------+---------------+---------------+
# |          |     n = 4     |     n = 16    |     n = 64    |
# +----------+---------------+---------------+---------------+
# | x = 0.25 |  1.0314130995 | 1.03141309988 | 1.03141309988 |
# | x = 0.5  | 1.12762586833 | 1.12762596521 | 1.12762596521 |
# |  x = 1   | 1.54305583323 | 1.54308063482 | 1.54308063482 |
# |  x = 2   | 3.75584648473 | 3.76219569108 | 3.76219569108 |
# +----------+---------------+---------------+---------------+
#
#
# Relative Error:
# +----------+---------------+--------+--------+
# |          |     n = 4     | n = 16 | n = 64 |
# +----------+---------------+--------+--------+
# | x = 0.25 | 99.9999999633 | 100.0  | 100.0  |
# | x = 0.5  | 99.9999914084 | 100.0  | 100.0  |
# |  x = 1   | 99.9983927225 | 100.0  | 100.0  |
# |  x = 2   | 99.8312366801 | 100.0  | 100.0  |
# +----------+---------------+--------+--------+
